# %% [markdown]
# # WeatherSense ML Notebook
#
# This notebook outlines the forecasting pipeline and evaluation strategy for the WeatherSense portfolio project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


,


,
,
15
